# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## List of Company(Tata Company)

# %%
Data = {
     "Location" : [' Jamshedpur (Jharkhand)',' Pune (Maharashtra)',' Lucknow (Uttar Pradesh)', 'Pantnagar (Uttarakhand)', 'Dharwad (Karnataka)',' Sanand (Gujarat)','Bangladesh',' Bhutan',' Sri Lanka ',' Italy' , 'Spain' , 'Poland' , ' Romania' , ' Turkey' , 'Chile' , ' South Africa',' Oman','Kuwait','Qatar','Saudi Arabia','United Arab Emirates','Bahrain','Iraq','Syria ',' Australia'],
    "Years":[1908,1964,1992,2007,2010,2010,2000,2000,1990,2008,2008,2000,2000,2000,pd.NaT,pd.NaT,pd.NaT,pd.NaT,pd.NaT,pd.NaT,pd.NaT,pd.NaT,pd.NaT,pd.NaT,pd.NaT],
    "Cars":['Tata Nano','Tata Indica','Tata Indigo','Tata Tiago','Tata Tigor','Tata Altroz','Tata Nexon','Tata Harrier','Tata Safari','Tata Sumo','Tata Hexa','Tata Zest','Tata Bolt','Tata Vista','Tata Manza','Tata Aria','Tata Xenon','Tata Estate','Tata Sierra','Tata Safari Storme','Tata Sumo Grande','Tata Winger','Tata Magic','Tata Venture','Tata Nano Twist']
    }

# %%
df=pd.DataFrame(Data)

# %%
df
# Out:
#                     Location Years                Cars
# 0     Jamshedpur (Jharkhand)  1908           Tata Nano
# 1         Pune (Maharashtra)  1964         Tata Indica
# 2    Lucknow (Uttar Pradesh)  1992         Tata Indigo
# 3    Pantnagar (Uttarakhand)  2007          Tata Tiago
# 4        Dharwad (Karnataka)  2010          Tata Tigor
# 5           Sanand (Gujarat)  2010         Tata Altroz
# 6                 Bangladesh  2000          Tata Nexon
# 7                     Bhutan  2000        Tata Harrier
# 8                 Sri Lanka   1990         Tata Safari
# 9                      Italy  2008           Tata Sumo
# 10                     Spain  2008           Tata Hexa
# 11                    Poland  2000           Tata Zest
# 12                   Romania  2000           Tata Bolt
# 13                    Turkey  2000          Tata Vista
# 14                     Chile   NaT          Tata Manza
# 15              South Africa   NaT           Tata Aria
# ...

# %%
df.to_csv('My_Company_project.csv')

# %%
df
# Out:
#                     Location Years                Cars
# 0     Jamshedpur (Jharkhand)  1908           Tata Nano
# 1         Pune (Maharashtra)  1964         Tata Indica
# 2    Lucknow (Uttar Pradesh)  1992         Tata Indigo
# 3    Pantnagar (Uttarakhand)  2007          Tata Tiago
# 4        Dharwad (Karnataka)  2010          Tata Tigor
# 5           Sanand (Gujarat)  2010         Tata Altroz
# 6                 Bangladesh  2000          Tata Nexon
# 7                     Bhutan  2000        Tata Harrier
# 8                 Sri Lanka   1990         Tata Safari
# 9                      Italy  2008           Tata Sumo
# 10                     Spain  2008           Tata Hexa
# 11                    Poland  2000           Tata Zest
# 12                   Romania  2000           Tata Bolt
# 13                    Turkey  2000          Tata Vista
# 14                     Chile   NaT          Tata Manza
# 15              South Africa   NaT           Tata Aria
# ...

# %%
Data2 = pd.DataFrame(np.random.rand(334,5) , index = np.arange(334))
Data2
# Out:
#             0         1         2         3         4
# 0    0.696394  0.039453  0.639611  0.531315  0.250448
# 1    0.371656  0.387826  0.836778  0.359981  0.667051
# 2    0.099498  0.037922  0.528292  0.413872  0.809312
# 3    0.820938  0.230752  0.967750  0.641465  0.879471
# 4    0.077032  0.655934  0.441868  0.534449  0.901424
# ..        ...       ...       ...       ...       ...
# 329  0.223795  0.993241  0.106118  0.069445  0.254777
# 330  0.904636  0.519966  0.927681  0.703636  0.714543
# 331  0.042284  0.670539  0.944616  0.465147  0.438696
# 332  0.705182  0.747165  0.305552  0.182890  0.006263
# 333  0.333004  0.586740  0.359038  0.890696  0.644949
#
# [334 rows x 5 columns]

# %%
df.to_csv('FMy_Company_project_False.csv'  , index = False)

# %%
df
# Out:
#                     Location Years                Cars
# 0     Jamshedpur (Jharkhand)  1908           Tata Nano
# 1         Pune (Maharashtra)  1964         Tata Indica
# 2    Lucknow (Uttar Pradesh)  1992         Tata Indigo
# 3    Pantnagar (Uttarakhand)  2007          Tata Tiago
# 4        Dharwad (Karnataka)  2010          Tata Tigor
# 5           Sanand (Gujarat)  2010         Tata Altroz
# 6                 Bangladesh  2000          Tata Nexon
# 7                     Bhutan  2000        Tata Harrier
# 8                 Sri Lanka   1990         Tata Safari
# 9                      Italy  2008           Tata Sumo
# 10                     Spain  2008           Tata Hexa
# 11                    Poland  2000           Tata Zest
# 12                   Romania  2000           Tata Bolt
# 13                    Turkey  2000          Tata Vista
# 14                     Chile   NaT          Tata Manza
# 15              South Africa   NaT           Tata Aria
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                     Location Years                Cars
# 0     Jamshedpur (Jharkhand)  1908           Tata Nano
# 1         Pune (Maharashtra)  1964         Tata Indica
# 2    Lucknow (Uttar Pradesh)  1992         Tata Indigo
# 3    Pantnagar (Uttarakhand)  2007          Tata Tiago
# 4        Dharwad (Karnataka)  2010          Tata Tigor
# 5           Sanand (Gujarat)  2010         Tata Altroz
# 6                 Bangladesh  2000          Tata Nexon
# 7                     Bhutan  2000        Tata Harrier
# 8                 Sri Lanka   1990         Tata Safari
# 9                      Italy  2008           Tata Sumo
# 10                     Spain  2008           Tata Hexa
# 11                    Poland  2000           Tata Zest
# 12                   Romania  2000           Tata Bolt
# 13                    Turkey  2000          Tata Vista
# 14                     Chile   NaT          Tata Manza
# ...

# %%
df.dropna(how='all', axis=1)
# Out:
#                     Location Years                Cars
# 0     Jamshedpur (Jharkhand)  1908           Tata Nano
# 1         Pune (Maharashtra)  1964         Tata Indica
# 2    Lucknow (Uttar Pradesh)  1992         Tata Indigo
# 3    Pantnagar (Uttarakhand)  2007          Tata Tiago
# 4        Dharwad (Karnataka)  2010          Tata Tigor
# 5           Sanand (Gujarat)  2010         Tata Altroz
# 6                 Bangladesh  2000          Tata Nexon
# 7                     Bhutan  2000        Tata Harrier
# 8                 Sri Lanka   1990         Tata Safari
# 9                      Italy  2008           Tata Sumo
# 10                     Spain  2008           Tata Hexa
# 11                    Poland  2000           Tata Zest
# 12                   Romania  2000           Tata Bolt
# 13                    Turkey  2000          Tata Vista
# 14                     Chile   NaT          Tata Manza
# 15              South Africa   NaT           Tata Aria
# ...

# %%
df.drop_duplicates(subset=['Years'])
# Out:
#                     Location Years         Cars
# 0     Jamshedpur (Jharkhand)  1908    Tata Nano
# 1         Pune (Maharashtra)  1964  Tata Indica
# 2    Lucknow (Uttar Pradesh)  1992  Tata Indigo
# 3    Pantnagar (Uttarakhand)  2007   Tata Tiago
# 4        Dharwad (Karnataka)  2010   Tata Tigor
# 6                 Bangladesh  2000   Tata Nexon
# 8                 Sri Lanka   1990  Tata Safari
# 9                      Italy  2008    Tata Sumo
# 14                     Chile   NaT   Tata Manza

# %%
df.isnull()
# Out:
#     Location  Years   Cars
# 0      False  False  False
# 1      False  False  False
# 2      False  False  False
# 3      False  False  False
# 4      False  False  False
# 5      False  False  False
# 6      False  False  False
# 7      False  False  False
# 8      False  False  False
# 9      False  False  False
# 10     False  False  False
# 11     False  False  False
# 12     False  False  False
# 13     False  False  False
# 14     False   True  False
# 15     False   True  False
# 16     False   True  False
# 17     False   True  False
# 18     False   True  False
# 19     False   True  False
# 20     False   True  False
# 21     False   True  False
# 22     False   True  False
# 23     False   True  False
# 24     False   True  False

# %%
df.notnull()
# Out:
#     Location  Years  Cars
# 0       True   True  True
# 1       True   True  True
# 2       True   True  True
# 3       True   True  True
# 4       True   True  True
# 5       True   True  True
# 6       True   True  True
# 7       True   True  True
# 8       True   True  True
# 9       True   True  True
# 10      True   True  True
# 11      True   True  True
# 12      True   True  True
# 13      True   True  True
# 14      True  False  True
# 15      True  False  True
# 16      True  False  True
# 17      True  False  True
# 18      True  False  True
# 19      True  False  True
# 20      True  False  True
# 21      True  False  True
# 22      True  False  True
# 23      True  False  True
# 24      True  False  True

# %% [markdown]
# ## Making plot

# %%
plt.plot(Data)
plt.show()

# %%
f = plt.figure()
f.set_figwidth(4)
f.set_figheight(1)
f

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2007,2010]
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Making Bar graph

# %%
f = plt.figure()
f.set_figwidth(4)
f.set_figheight(1)
f

# %%
plt.bar(x,y)
plt.show()

# %%
plt.xlabel("Location",fontsize = 20)
plt.ylabel("Years",fontsize = 20)
plt.bar(x,y, edgecolor ="r",width=0.4,linewidth = 2 , linestyle = ":")
plt.show()

# %%
plt.xlabel("Location",fontsize = 20)
plt.ylabel("Years",fontsize = 20)
p=np.arange(len(x))
plt.bar(p,y, edgecolor ="r",width=0.2,linewidth = 1 , linestyle = ":")
plt.show()

# %%
plt.xlabel("Location",fontsize = 20)
plt.ylabel("Years",fontsize = 20)
p=np.arange(len(x))

width=0.2
p1=(j+width for j in p)

plt.bar(p,y,width,edgecolor ="r",linewidth = 1 , linestyle = ":")
plt.show()

# %%
plt.xlabel("Location",fontsize = 20)
plt.ylabel("Years",fontsize = 20)
p=np.arange(len(x))

width=0.2
p1=(j+width for j in p)

plt.xticks(p+width,x)
plt.bar(p,y,width,edgecolor ="r",linewidth = 1 , linestyle = ":")
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
z= [1080,1071,182,1073,1039]
plt.xlabel("Location",fontsize = 20)
plt.ylabel("Years",fontsize = 20)

width = 0.2
plt.bar(x,y,width, color = 'm' ,edgecolor ="r",linewidth = 2 , linestyle = ":" , align = "edge", label = 'First_company')
plt.bar(x,z,width, color = "y", edgecolor ="r",linewidth = 2 , linestyle = ":" , align = "edge" ,label = 'Second_company')

plt.legend()
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
z= [1080,1071,182,1073,1039]
plt.xlabel("Location",fontsize = 20)
plt.ylabel("Years",fontsize = 20)
p=np.arange(len(x))

width = 0.2
p1=(j+width for j in p)

plt.xticks(p+width,x)
plt.bar(x,y,width, color = 'm' ,edgecolor ="r",linewidth = 2 , linestyle = ":" , align = "edge", label = 'First_company')
plt.bar(x,z,width, color = "y", edgecolor ="r",linewidth = 2 , linestyle = ":" , align = "edge" ,label = 'Second_company')

plt.legend()
plt.show()

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
from matplotlib import style

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
z= [1080,1071,182,1073,1039]
plt.xlabel("Location",fontsize = 20)
plt.ylabel("Years",fontsize = 20)
p=np.arange(len(x))

width = 0.2
p1=(j+width for j in p)

plt.xticks(p+width,x)
plt.bar(x,y,width, color = 'm' ,edgecolor ="r",linewidth = 2 , linestyle = ":" , align = "edge", label = 'First_company')
plt.bar(p+0.2,z,width, color = "y", edgecolor ="r",linewidth = 2 , linestyle = ":" , align = "edge" ,label = 'Second_company')
# plt.bar(p+0.4,z,width, color = "b", edgecolor ="r",linewidth = 2 , linestyle = ":" , align = "edge" ,label = 'Third_company')


plt.legend()
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
z= [1080,1071,182,1073,1039]
plt.xlabel("Location",fontsize = 20)
plt.ylabel("Years",fontsize = 20)
p=np.arange(len(x))

width = 0.2
p1=(j+width for j in p)

plt.xticks(p+width,x)
plt.bar(x,y,width, color = 'm' ,edgecolor ="r",linewidth = 2 , linestyle = ":" , align = "edge", label = 'First_company')
plt.bar(p+0.2,z,width, color = "y", edgecolor ="r",linewidth = 2 , linestyle = ":" , align = "edge" ,label = 'Second_company')

plt.xticks(p+width/2,x,rotation=20)
plt.legend()
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
z= [1080,1071,182,1073,1039]
plt.xlabel("Location",fontsize = 20)
plt.ylabel("Years",fontsize = 20)
p=np.arange(len(x))

width = 0.2
p1=(j+width for j in p)

plt.xticks(p+width,x)
plt.barh(p,y,width, color = 'm' ,edgecolor ="r",linewidth = 2 , linestyle = ":" , align = "edge", label = 'First_company')
plt.barh(p+0.2,z,width, color = "y", edgecolor ="r",linewidth = 2 , linestyle = ":" , align = "edge" ,label = 'Second_company')

plt.xticks(p+width/2,x,rotation=20)
plt.legend()
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
z= [1080,1071,182,1073,1039]
plt.xlabel("Location",fontsize = 20)
plt.ylabel("Years",fontsize = 20)
p=np.arange(len(x))

width = 0.2
p1=(j+width for j in p)

plt.xticks(p+width,x)
plt.barh(x,y,width, color = 'm' ,edgecolor ="r",linewidth = 2 , linestyle = ":" , align = "edge", label = 'First_company')
plt.barh(x,z,width, color = "y", edgecolor ="r",linewidth = 2 , linestyle = ":" , align = "edge" ,label = 'Second_company')

plt.xticks(p+width/2,x,rotation=20)
plt.legend()
plt.show()

# %% [markdown]
# ## Making scatter graph

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
colors = ["r","g","b","b","y"]
plt.xlabel("Location",fontsize = 20)
plt.ylabel("Years",fontsize = 20)
plt.scatter(x,y,c= colors)
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
sizes = [200,300,200,300,300]
colors = ['m',"g","b","b","y"]
plt.xlabel("Location",fontsize = 20)
plt.ylabel("Years",fontsize = 20)
plt.scatter(x,y,c= colors,s=sizes , marker="*",edgecolor = "r" , linewidth = 2)
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
sizes = [200,300,200,300,300]
colors = [10,49,30,56,20]
plt.xlabel("Location",fontsize = 20)
plt.ylabel("Years",fontsize = 20)
plt.scatter(x,y,c= colors,s=sizes ,edgecolor = "r" , linewidth = 2 , cmap="viridis")
plt.colorbar()
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
z= [1080,1071,182,1073,1039]
sizes = [200,300,200,300,300]
colors = [10,49,30,56,20]
plt.xlabel("Location",fontsize = 20)
plt.ylabel("Years",fontsize = 20)
plt.scatter(x,y,c= colors,s=sizes ,edgecolor = "r" , linewidth = 2 , cmap="viridis")
plt.scatter(x,z,c= colors,s=sizes ,edgecolor = "g" , linewidth = 2 , cmap="viridis")
plt.colorbar()
plt.show()

# %% [markdown]
# ## Making Hist Graph

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
plt.hist(x)
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
plt.hist(x,"auto",(0,5),edgecolor="g")
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
l =[10,20,30,40,40]
plt.hist(x,color="y", edgecolor="g", histtype = "bar" , orientation="horizontal" , log = True)
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
plt.pie(y,labels=x)
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
ex = [0.4,0.0,0.0,0.0,0.0]
plt.pie(y,labels=x,explode=ex)
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
ex = [0.4,0.0,0.0,0.0,0.0]
plt.pie(y,labels=x,explode=ex,autopct="%0.2f%%")
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
ex = [0.4,0.0,0.0,0.0,0.0]
plt.pie(y,labels=x,explode=ex,autopct="%0.2f%%",shadow = True)
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
ex = [0.4,0.0,0.0,0.0,0.0]
plt.pie(y,labels=x,explode=ex,autopct="%0.2f%%",shadow = True,radius = 1.5,labeldistance=1.1 , startangle = 180)
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
ex = [0.4,0.0,0.0,0.0,0.0]
plt.pie(y,labels=x,explode=ex,autopct="%0.2f%%",shadow = True,labeldistance=1.1 , startangle = 180,wedgeprops={"linewidth":6})
plt.show()

# %% [markdown]
# ## Making Stem Graph

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
plt.stem(x,y)
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
plt.stem(x,y,linefmt=":",markerfmt="r*",basefmt = "g", use_line_collection = False)
plt.show()

# %% [markdown]
# ## Making Box Plot

# %%
Years =[1908,1964,1992,2000,1100,1908,1964,1992,2007,2010,2010,2000,2000,1990,2008,2008,2000,2000,2000]
plt.boxplot(Years)
plt.show()

# %%
x =[1908,1964,1992,2000]
plt.boxplot(x)
plt.show()

# %%
x =[1908,1964,1992,2000]
plt.boxplot(x,notch=False,vert = False ,patch_artist = True)
plt.show()

# %%
x =[1908,1964,1992,2000]
plt.boxplot(x,widths=0.2)
plt.show()

# %%
x =[1908,1964,1992,2000]
plt.boxplot(x,notch=False,vert = False ,patch_artist = True,showmeans=True)
plt.show()

# %%
Years =[1908,1964,1992,2000,1100,1908,1964,1992,2007,2010,2010,2000,2000,1990,2008,2008,2000,2000,2000]
plt.boxplot(Years,whis = 20)
plt.show()

# %%
x =[1908,1964,1992,2000]
x1 = [1908,1964,1992,2007]
y=[x,x1]
plt.boxplot(y,notch=False,vert = False ,patch_artist = True,showmeans=True , boxprops=dict(color="r") ,capprops=dict(color="r"),whiskerprops = dict(color="r"))
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
y1=[1964,1992,2007,2010,2010]
y2=[2000,2000,1990,2008,2008]
plt.stackplot(x,y,y1,y2)
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
y1=[1964,1992,2007,2010,2010]
y2=[2000,2000,1990,2008,2008]
l = ["y1","y2","y3"]
plt.stackplot(x,y,y1,y2,labels=l,baseline="sym")
plt.legend(loc=2)
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
plt.step(x,y,marker="o")
plt.grid()
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
plt.step(x,y,marker="o",ms=10,mfc="g",color='m',label="python")
plt.legend(loc=2)
plt.grid()
plt.show()

# %% [markdown]
# ## Making Fill_Between

# %%
x =[2000,2000,1990,2008,2008]
y =[1908,1964,1992,2000,1100]
plt.plot(x,y,color="r")
plt.show()

# %%
x =[2000,2000,1990,2008,2008]
y =[1908,1964,1992,2000,1100]
plt.plot(x,y,color="r")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
x =[2000,2000,1990,2008,2008]
y =[1908,1964,1992,2000,1100]
plt.plot(x,y,color="r")
plt.fill_between(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
x =[2000,2000,1990,2008,2008]
y =[1908,1964,1992,2000,1100]
plt.plot(x,y,color="r")
plt.fill_between(x ,y,color = "g" )
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %% [markdown]
# ## Making Subplot

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
plt.plot(x,y,color = 'm')
# plt.pie([1],color="r")
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
plt.plot(x,y,color = 'm')
plt.pie([1],colors="r")
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
plt.plot(x,y,color = 'm')
plt.pie([1],colors="r")
y1 =[1908,1964,1992,2000,1100]
plt.pie(y1)
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
plt.plot(x,y,color = 'm')
plt.pie([1],colors="r")
y1 =[1908,1964,1992,2000,1100]
plt.pie(y1)

x1 = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y2 =[1908,1964,1992,2000,1100]
plt.bar(x1,y2)
plt.show()

# %%
x = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y =[1908,1964,1992,2000,1100]
plt.subplot(2,2,1)
plt.plot(x,y,color = 'm')

plt.subplot(2,2,2)
plt.pie([1],colors="r")

plt.subplot(2,2,3)
y1 =[1908,1964,1992,2000,1100]
plt.pie(y1)

plt.subplot(2,2,4)
x1 = ['Jharkhand',' Maharashtra ',' UttarPradesh', 'Uttarakhand', 'Karnataka']
y2 =[1908,1964,1992,2000,1100]
plt.bar(x1,y2)
plt.show()

# %% [markdown]
# ## Thie project is helpful for Machine-Learner
